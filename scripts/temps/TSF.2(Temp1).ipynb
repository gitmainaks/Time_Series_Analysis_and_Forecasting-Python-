# %% [markdown]
# ## Useful Code Template

# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import month_plot, quarter_plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the data
# Loading the Data and Setting the Index
df = pd.read_csv("TSF.2.bitcoin_price.csv", index_col = "Date", parse_dates=True)
df.head()

# %% [markdown]
# Exploratory Data Analysis

# %%
# Daily Closing Price
df['Close'].plot(title='Daily Closing Price')
plt.show()

# %%
# Plotting the monthly seasonality
month_plot(df['Close'].resample('M').mean(), ylabel='Closing')
plt.show()

# %%
# Plotting the quarterly seasonality
quarter_plot(df['Close'].resample('Q').mean(), ylabel='Closing')
plt.show()

# %%
# Seasonal Decomposition Plots for Bitcoin Data
decomposition = seasonal_decompose(df['Close'],
                                    model='multiplicative',
                                    period=365)

fig = decomposition.plot()
fig.set_size_inches(10,8)
plt.show()

# %%
# Plot the autocorrelation (ACF)
fig, ax = plt.subplots(figsize=(10,6))
plot_acf(df['Close'], lags = 100, ax=ax)
plt.show()

# %%
# Plot the partial autocorrelation (PACF)
fig, ax = plt.subplots(figsize=(10,6))
plot_pacf(df['Close'], lags = 100, ax=ax)
plt.show()

# %% [markdown]
#  Learning from the False Forecast:
#
#  Key takeaways-
#  1) Is this trend really here to stay? Is it just a passing craze? (Consider the Longevity of a trend)
#  2) Long-Term Capital Management's Mathematical Mishap (LTCM)
#  3) Google Flu Trends (A Misstep in Big Data Predictions)
#  4) The Hindenburg Omen (An Ominous Market Predictor?)
#
#  Conclusion; Embracing the Unpredictability
